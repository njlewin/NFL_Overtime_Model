# %%
from simulation.overtime_period import Overtime_Period
import pandas as pd
import numpy as np

# %%
def select_drive(drive_list: pd.DataFrame, yardline: float,time_remaining: float, score_diff: float) -> pd.Series:
    """
    Given a list of historical drives and a game situation, returns a
    randomly sampled drive from the top 5% most similar historical drives.

    Similarity is measured by weighted Euclidean distance across:
      - Field position (yardline)
      - Time remaining (non-linear — more sensitive late in game)
      - Score differential
    """

    # --- Normalization constants ---
    MAX_YARDLINE = 99.0
    MAX_TIME = 600.0  # 10 min OT period
    MAX_SCORE_DIFF = 7.0
    TIME_LAMBDA = 0.004  # controls how aggressively late-game time is weighted

    # --- Weights ---
    W_YARDLINE = 0.45
    W_TIME = 0.1
    W_SCORE = 0.45

    # --- Compute deltas (normalized) ---
    d_yardline = (drive_list["start_yardline"] - yardline) / MAX_YARDLINE
    d_time = (drive_list["start_time_left"] - time_remaining) / MAX_TIME
    d_score = (drive_list["start_score_diff"] - score_diff) / MAX_SCORE_DIFF

    # --- Non-linear time sensitivity ---
    # Grows exponentially as time_remaining approaches 0
    time_sensitivity = np.exp(TIME_LAMBDA * (MAX_TIME - time_remaining))

    # --- Weighted Euclidean distance ---
    df["_distance"] = np.sqrt(
        W_YARDLINE * d_yardline**2 +
        W_TIME     * time_sensitivity * d_time**2 +
        W_SCORE    * d_score**2
    )

    # --- Select top 1 closest drives and sample ---
    candidates = df.nsmallest(10, "_distance")

    display(candidates)
    print(len(candidates))

    # --- Random sample from candidates ---
    return candidates.drop(columns="_distance").sample(n=1).iloc[0]

# %%
OT = Overtime_Period('Team A', 'Team B', 'Team A')
OT.simulate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 2
#       1 OT = Overtime_Period('Team A', 'Team B', 'Team A')
# ----> 2 OT.simulate()
#
# File ~\PycharmProjects\NFL_Overtime_Model\overtime_period.py:30, in simulate(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\PycharmProjects\NFL_Overtime_Model\overtime_period.py:36, in kickoff(self, kickoff_team)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ValueError: 0 is not in list

# %%
aselect_drive(df, 35, 30, -3)
# Out:
#                  drive_id  start_yardline  start_time_left  \
# 9987   2017_12_JAX_ARI_29              35              1.0
# 17428   2018_16_GB_NYJ_23              38             65.0
# 56375    2025_05_SF_LA_18              50             42.0
# 28256   2020_13_LV_NYJ_24              50              4.0
# 49376   2024_02_TB_DET_21              44             33.0
# 13640  2018_04_PHI_TEN_21              39            101.0
# 9285   2017_10_LAC_JAX_29              52             58.0
# 9283   2017_10_LAC_JAX_27              36            108.0
# 53148  2024_14_NYJ_MIA_18              54             44.0
# 37776  2022_05_LAC_CLE_20              45             70.0
#
#        start_posteam_score  start_defteam_score  start_score_diff  \
# 9987                  24.0                 27.0              -3.0
# 17428                 35.0                 38.0              -3.0
# 56375                 20.0                 23.0              -3.0
# 28256                 28.0                 31.0              -3.0
# 49376                 16.0                 20.0              -4.0
# 13640                 17.0                 20.0              -3.0
# 9285                  14.0                 17.0              -3.0
# 9283                  14.0                 17.0              -3.0
# 53148                 23.0                 26.0              -3.0
# 37776                 28.0                 30.0              -2.0
#
#        drive_result  time_elapsed  defteam_TD  posteam_score_change  \
# 9987         FUMBLE           0.0       False                   0.0
# 17428    FIELD_GOAL          44.0       False                   3.0
# 56375    FIELD_GOAL          36.0       False                   3.0
# 28256      END_GAME           0.0       False                   0.0
# 49376         DOWNS          27.0       False                   0.0
# 13640    FIELD_GOAL          80.0       False                   3.0
# 9285     FIELD_GOAL          38.0       False                   3.0
# 9283   INTERCEPTION          15.0       False                   0.0
# 53148    FIELD_GOAL          32.0       False                   3.0
# 37776     MISSED_FG          54.0       False                   0.0
#
#        defteam_score_change  last_play_yardline  next_drive_start_yardline  \
# 9987                    0.0                35.0                       35.0
# 17428                   0.0                15.0                       75.0
# 56375                   0.0                30.0                       60.0
# 28256                   0.0                50.0                       50.0
# 49376                   0.0                26.0                       73.0
# 13640                   0.0                12.0                       75.0
# 9285                    0.0                16.0                       78.0
# 9283                    0.0                37.0                       90.0
# 53148                   0.0                34.0                       70.0
# 37776                   0.0                35.0                       56.0
#
#        _distance
# 9987    0.047791
# 17428   0.061156
# 56375   0.103545
# 28256   0.110302
# 49376   0.113698
# 13640   0.120103
# 9285    0.124089
# 9283    0.128719
# 53148   0.130794
# 37776   0.134611
# 10
# drive_id                     2017_12_JAX_ARI_29
# start_yardline                               35
# start_time_left                             1.0
# start_posteam_score                        24.0
# start_defteam_score                        27.0
# start_score_diff                           -3.0
# drive_result                             FUMBLE
# time_elapsed                                0.0
# defteam_TD                                False
# posteam_score_change                        0.0
# defteam_score_change                        0.0
# last_play_yardline                         35.0
# next_drive_start_yardline                  35.0
# Name: 9987, dtype: object
